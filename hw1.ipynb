# %% [markdown]
# # Homework 1

# %% [markdown]
# ## Q1
# From the plot, we can observe two important things about the race distribution.
# First, one race group has much larger count compared to others. This means most of the people in this dataset belong to that race.
# Second, some race groups have very small counts. So the dataset is not balanced. There is one dominant race group and some minority groups.

# %% [markdown]
# ## Q2
# Sometimes it is better to show percentage instead of real count in bar plot. Percentage helps us understand the proportion of each group. If total sample size is big, real count can be confusing.
# Also, if we compare two datasets with different total size, percentage makes comparison easier and more fair.
# One improvement to the plot is adding value labels on top of each bar. Also rotating x-axis labels can make it more readable if they overlap.

# %% [markdown]
# ## Q3
# One possible problem in the plot is that the y-axis does not start from zero. This can make the difference between groups look bigger than it actually is.
# To fix this problem, the y-axis should start from zero. This makes the visualization more accurate and honest.

# %% [markdown]
# ## Q4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("Salaries.csv")

# Preview data
df.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %% [markdown]
# ### Scatter Plot: Salary vs Years Since PhD

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["yrs.since.phd"], df["salary"])

plt.title("Salary vs Years Since PhD")
plt.xlabel("Years Since PhD")
plt.ylabel("Salary")

plt.show()

# %% [markdown]
# ### Scatter + Linear Smooth Line

# %%
plt.figure(figsize=(8,6))

sns.regplot(x="yrs.since.phd", y="salary", data=df)

plt.title("Salary vs Years Since PhD with Linear Fit")
plt.xlabel("Years Since PhD")
plt.ylabel("Salary")

plt.show()

# %% [markdown]
# ### Scatter Colored by Rank + Linear Line

# %%
plt.figure(figsize=(8,6))

sns.lmplot(x="yrs.since.phd",
           y="salary",
           hue="rank",
           data=df,
           height=6,
           aspect=1.2)

plt.title("Salary vs Years Since PhD by Rank")

plt.show()
